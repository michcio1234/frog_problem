# %%
from functools import lru_cache

# Just to draw the result:
import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib.ticker import MaxNLocator

# %% [markdown]
# ## Solution

# %%
@lru_cache()
def exp_jumps(n):
    """
    Expected number of jumps for a distance of n.
    
    "Distance" means the whole distance to travel,
    i.e. if there is one leaf between river banks,
    the distance is 2 (1 jump on the leaf and 1 jump
    on the bank).
    """
    if n < 0:
        raise ValueError("Distance cannot be negative.")
    if n == 0:
        return 0
    if n == 1:
        return 1
    return 1 + sum(1/n * exp_jumps(i+1) for i in range(n-1))

# %% [markdown]
# ## Drawing

# %%
x = list(range(0, 21))
y = [exp_jumps(i) for i in x]

# %%
plt.plot(x, y, '.-')
plt.grid(True)
ax = plt.gca()
ax.xaxis.set_major_locator(MaxNLocator(integer=True))
plt.xlabel('Distance')
plt.ylabel('Expected number of jumps')
None
